# %%
a=2
b=3
c=4
print(a,b,c,)
# Out:
# 2 3 4

# %%
a=23
print(f"value is {a}") # formatted string literal
# Out:
# value is 23

# %%
print("Hello",end=" ")
print("world")
# Out:
# Hello world

# %%
a=23,34
a
# Out:
# (23, 34)

# %%
a=(23,45,57,68,)
a
# Out:
# (23, 45, 57, 68)

# %%
#List, tuple, set, dictionary
#Integer
x=23
# float
a= 23.3
# string
X = "hello"
# boolean
D=True and False

# %%
a=23
b=34
a,b
# Out:
# (23, 34)

# %%
a,*b=2,3,4
b
# Out:
# [3, 4]

# %%
print(b)
# Out:
# [3, 4]

# %%
print(a)
# Out:
# 2

# %%
b
a
# Out:
# 2

# %%
a
b
# Out:
# [3, 4]

# %%
*a,b=2,3,4,5,65
print(a)
print(b)
# Out:
# [2, 3, 4, 5]
# 65

# %%
a,*b,c,d=1,2,3,4,5,6,7,5
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# [2, 3, 4, 5, 6]
# 7
# 5

# %%
a=23 #(int)
b="abhay" #(string)
c=23.2  #(float)
#its primitive data type

# %%
a=2+3j
type(a)
# Out:
# complex

# %%
a=23
float(a)
# Out:
# 23.0

# %%
a
# Out:
# 23

# %%
"5"=="a"
# Out:
# False

# %%
a=23
float(a)
# Out:
# 23.0

# %%
2+3==5
# Out:
# True

# %%
a=45.2
int(a)
# Out:
# 45

# %%
type(a)
# Out:
# float

# %%
a=45
type(a)
# Out:
# int

# %%
print(float(a))
# Out:
# 45.0

# %%
type(a)
# Out:
# int

# %%
a=float(a)
a
type(a)
# Out:
# float

# %%
a=45.34
a=int(a)
a
type(a)
# Out:
# int

# %%
a=23
a=str(a)
type(a)
# Out:
# str

# %%
a=34
a=bool(a)
a
# Out:
# True

# %%
a= 3+2j
type(a)
# Out:
# complex

# %%
a
# Out:
# (3+2j)

# %%
a=float()
type(a)
a
# Out:
# 0.0

# %%
a=int(a)
type(a)
a
# Out:
# 0

# %%
a=2+3j
a
# Out:
# (2+3j)

# %%
type(a)
# Out:
# complex

# %%
a
# Out:
# (2+3j)

# %%
# 5>3
5>3
# Out:
# True

# %%
"apple"=="Apple"
# Out:
# False

# %%
not False
# Out:
# True

# %%
1==True
# Out:
# True

# %%
x=12.6
print(type(x))
# Out:
# <class 'float'>

# %%
y=23
print(type(y))
# Out:
# <class 'int'>

# %%
ALL = 23
print(ALL)
# Out:
# 23

# %%
a="5"
a
type(a)
# Out:
# str

# %%
a="5"
b=2
c=int(a)+b
d=a*b
print(c)
print(d)
# Out:
# 7
# 55

# %%
d
# Out:
# '55'

# %%
x =True
y = False
print(x+y)
print(x-y)
print(y-x)
print(x*y)
print(x+x)
print(x+5)
# Out:
# 1
# 1
# -1
# 0
# 2
# 6

# %%
x =2
y=3
x ,y = y,x
print(x)
print(y)
# Out:
# 3
# 2

# %%
temp=x
x=y
y=temp
x
# Out:
# 3

# %%
a=x
x=y
y=a
x
# Out:
# 3

# %%
a=[2,3,4,5]
a.insert(2,4)
print(a)
# Out:
# [2, 3, 4, 4, 5]

# %%
a
# Out:
# [2, 3, 4, 4, 5]

# %%
a.insert(4,5,)
a
# Out:
# [2, 3, 4, 4, 5, 5, 5]

# %%
a=[2,3,4]
b=[3,5,6]
c=a+b
print(c)
# Out:
# [2, 3, 4, 3, 5, 6]

# %%
x=[1,3,4]
a,b,c=x
print(a)
print(b)
print(c)
# Out:
# 1
# 3
# 4

# %%
a='abhay''kumar''ajay'
print(a)
# Out:
# abhaykumarajay

# %%
print(a,sep="/")
# Out:
# abhaykumarajay

# %%
a="abhay"
b="kumar"
c="singh"
print(a,b,c)
# Out:
# abhay kumar singh

# %%
a=3
b=4
c=5
print(a,b,c)
# Out:
# 3 4 5

# %%
a=range(1,10)
print(a)
# Out:
# range(1, 10)

# %%
print(list(a))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(tuple(a))
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
print(set(a))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s={1,2,3,2,3,4,5,4,6,5}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
d = {"a": 1, "b": 2}
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
d  =dict(a=1,b=2)
d
# Out:
# {'a': 1, 'b': 2}

# %%
d = dict([("a", 1),("b", 2)])
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
a,b,c=[1,2,3]
print(a,b,c)
# Out:
# 1 2 3

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a=5;b=40;c=90
print(a)
print(b)
print(c)
# Out:
# 5
# 40
# 90

# %%
print(a,end=" ")
print(b,end=" ")
print(c,end=" ")
# Out:
# 5 40 90

# %%
a= input("Enter Your Name: ")
# Out:
# ''

# %%
a= input('Enter Your Name:')

# %%
input("enter age")

# %%
input()

# %%
a="hello"
a
# Out:
# 'hello'

# %%
input("Enter Your Name: ")

# %%
a=12

# %%
a=12
b=2

# %%
a+b
# Out:
# 14

# %%
a-b
# Out:
# 10

# %%
a*b
# Out:
# 24

# %%
a/b
# Out:
# 6.0

# %%
a//b
# Out:
# 6

# %%
a=13
b=2
a//b
# Out:
# 6

# %%
a/b
# Out:
# 6.5

# %%
a**b
# Out:
# 169

# %%
a%b
# Out:
# 1

# %%
a=5
b=2
a%b
# Out:
# 1

# %%
a//b
# Out:
# 2

# %%
a=10
b=8
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>2 and b<2
# Out:
# False

# %%
a<2 or b>2
# Out:
# True

# %%
x=20
y=a+x
y
# Out:
# 30

# %%
a
# Out:
# 10

# %%
print("hi"*3)
# Out:
# hihihi

# %%
print([1,2,3]*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a=10
a*=2
print(a)
# Out:
# 20

# %%
a=4
b=5
a>4
# Out:
# False

# %%
print(a)
print(b)
a,b=b,a
print(a)
print(b)
# Out:
# 4
# 5
# 5
# 4

# %%
a=b
b=a
print(a)
print(b)
# Out:
# 4
# 4

# %%
a=23
b=str(a)
type(b)
# Out:
# str

# %%
a
# Out:
# 23

# %%
b
# Out:
# '23'

# %%
a=34
a=str(a)
print(a)
# Out:
# 34

# %%
type(a)
# Out:
# str

# %%
a=34
b=45
print(a)
print(b)
# Out:
# 34
# 45

# %%
print(a+b)
# Out:
# 79

# %%
a=3,4
b=5
c=6
print(a,b,c)
# Out:
# (3, 4) 5 6

# %%
print(a);print(b);print(c)
# Out:
# (3, 4)
# 5
# 6

# %%
print(a)
print(b)
print(c)
# Out:
# (3, 4)
# 5
# 6

# %%
print(a,end=" ")
print(b,end=" ")
print(c,end=" ")
# Out:
# (3, 4) 5 6

# %%
print(a,"\n",b,"\n",c,"\n")
# Out:
# (3, 4)
#  5
#  6

# %%
a=b=10
print(a,b,c)
# Out:
# 10 10 10

# %%
x=y=z=30
print(x,y)
# Out:
# 30 30

# %%
a=input("Enter your Name")
print(a)
# Out:
# rishi

# %%
x=int(input("enter your x:"))
y=int(input("Enter your y"))

print(x+y)

# %%
c=
