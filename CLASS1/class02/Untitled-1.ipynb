# %%
import numpy as np

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "London", "Paris"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
df.head(1)
# Out:
#     Name  Age      City
# 0  Alice   25  New York

# %%
df.tail(1)
# Out:
#       Name  Age   City
# 2  Charlie   35  Paris

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,4),facecolor="skyblue")
sns.barplot(data=df,x="Name", y="Age",palette="rocket")
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_18276\3028522192.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x="Name", y="Age",palette="rocket")
# <Axes: xlabel='Name', ylabel='Age'>

# %%
data = (['name':'Rahul','age':20,'location':'Delhi','work':'job'])
# Out:
#   Cell In[3], line 1
#     data = (['name':'Rahul','age':20,'location':'Delhi','work':'job'])
#                    ^
# SyntaxError: invalid syntax

# %%
data.get('gupta','item not found in the data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.get('gupta','item not found in the data')
#
# NameError: name 'data' is not defined

# %%
data['qualification']='Graduation'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data['qualification']='Graduation'
#
# NameError: name 'data' is not defined

# %%
data['ramesh']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data['ramesh']
#
# NameError: name 'data' is not defined

# %%
a= 20
b= 22
c= a+b
print(c)
# Out:
# 42

# %%
list=[12,23,34]
type(list)
# Out:
# list

# %%
a=[12,11,232,3434]
type(a)
# Out:
# list

# %%
a= 'abhay'
print(a)
# Out:
# abhay

# %%
a
# Out:
# 'abhay'

# %%
type(a)
# Out:
# str

# %%
a =12

# %%
type(a)
# Out:
# int

# %%
a=12.2
type(a)
# Out:
# float

# %%
a= [12,23,122,'abhay', 56]
print(a)
# Out:
# [12, 23, 122, 'abhay', 56]

# %%
type(a)
# Out:
# list

# %%
a.append(56)
a
# Out:
# [12, 23, 122, 'abhay', 56, 56]

# %%
a.pop()
a
# Out:
# [12, 23, 122, 'abhay']

# %%
a
# Out:
# [12, 23, 122, 'abhay']

# %%
a
# Out:
# [12, 23, 122, 'abhay']

# %%
a.remove(122)
a
# Out:
# [12, 23, 'abhay']

# %%
a.insert(23,34)
a
# Out:
# [12, 23, 'abhay', 34, 34, 34, 34, 34]

# %%
a.pop()
a
# Out:
# [12, 23, 'abhay', 34, 34, 34, 34]
